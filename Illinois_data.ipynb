# %%
import pandas as pd

# %%
demo_csv = "Resources/acs2017_county_data.csv"

# %%
demo_df = pd.read_csv(demo_csv)
demo_df.head()
# Out:
#    CountyId    State          County  TotalPop    Men   Women  Hispanic  \
# 0      1001  Alabama  Autauga County     55036  26899   28137       2.7
# 1      1003  Alabama  Baldwin County    203360  99527  103833       4.4
# 2      1005  Alabama  Barbour County     26201  13976   12225       4.2
# 3      1007  Alabama     Bibb County     22580  12251   10329       2.4
# 4      1009  Alabama   Blount County     57667  28490   29177       9.0
#
#    White  Black  Native      ...       Walk  OtherTransp  WorkAtHome  \
# 0   75.4   18.9     0.3      ...        0.6          1.3         2.5
# 1   83.1    9.5     0.8      ...        0.8          1.1         5.6
# 2   45.7   47.8     0.2      ...        2.2          1.7         1.3
# 3   74.6   22.0     0.4      ...        0.3          1.7         1.5
# 4   87.4    1.5     0.3      ...        0.4          0.4         2.1
#
#    MeanCommute  Employed  PrivateWork  PublicWork  SelfEmployed  FamilyWork  \
# ...

# %%
new_demo_df = demo_df.loc[demo_df['State'] == 'Illinois']
new_demo_df
# Out:
#      CountyId     State              County  TotalPop      Men    Women  \
# 595     17001  Illinois        Adams County     66787    32698    34089
# 596     17003  Illinois    Alexander County      6776     3258     3518
# 597     17005  Illinois         Bond County     17034     8767     8267
# 598     17007  Illinois        Boone County     53638    26755    26883
# 599     17009  Illinois        Brown County      6791     4360     2431
# 600     17011  Illinois       Bureau County     33619    16506    17113
# 601     17013  Illinois      Calhoun County      4897     2453     2444
# 602     17015  Illinois      Carroll County     14704     7288     7416
# 603     17017  Illinois         Cass County     12880     6529     6351
# 604     17019  Illinois    Champaign County    207946   103843   104103
# 605     17021  Illinois    Christian County     33562    17040    16522
# 606     17023  Illinois        Clark County     15924     7827     8097
# ...

# %%
clean_demo_df = demo_df[["County", "TotalPop", "Income", "Poverty"]].copy()

# %%
clean_demo_df.head()
# Out:
#            County  TotalPop  Income  Poverty
# 0  Autauga County     55036   55317     13.7
# 1  Baldwin County    203360   52562     11.8
# 2  Barbour County     26201   33368     27.2
# 3     Bibb County     22580   43404     15.2
# 4   Blount County     57667   47412     15.6

# %%
employment_csv = "Resources/unemployment.csv"

# %%
employment_df = pd.read_csv(employment_csv)
employment_df.head()
# Out:
#    employment  labor_force  lausexnum  month              name  unemployment  \
# 0       30784        31892          1      4      Adams County          1108
# 1        2094         2251          2      4  Alexander County           157
# 2        7620         7924          3      4       Bond County           304
# 3       24240        26101          4      4      Boone County          1861
# 4        2884         2960          5      4      Brown County            76
#
#    unemprate  year
# 0        3.5  2017
# 1        7.0  2017
# 2        3.8  2017
# 3        7.1  2017
# 4        2.6  2017
